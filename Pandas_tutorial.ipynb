# %%
import pandas

# %%
df = pandas.read_csv('/home/shruti/Downloads/2016-pydata-carolinas-pandas-master/data/gapminder.tsv',sep='\t')

# %%
df
# Out:
#           country continent  year  lifeExp       pop    gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333   779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934   820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083   853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966   836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460   739.981106
# 5     Afghanistan      Asia  1977   38.438  14880372   786.113360
# 6     Afghanistan      Asia  1982   39.854  12881816   978.011439
# 7     Afghanistan      Asia  1987   40.822  13867957   852.395945
# 8     Afghanistan      Asia  1992   41.674  16317921   649.341395
# 9     Afghanistan      Asia  1997   41.763  22227415   635.341351
# 10    Afghanistan      Asia  2002   42.129  25268405   726.734055
# 11    Afghanistan      Asia  2007   43.828  31889923   974.580338
# 12        Albania    Europe  1952   55.230   1282697  1601.056136
# ...

# %%
print(df)
# Out:
#           country continent  year  lifeExp       pop    gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333   779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934   820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083   853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966   836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460   739.981106
# 5     Afghanistan      Asia  1977   38.438  14880372   786.113360
# 6     Afghanistan      Asia  1982   39.854  12881816   978.011439
# 7     Afghanistan      Asia  1987   40.822  13867957   852.395945
# 8     Afghanistan      Asia  1992   41.674  16317921   649.341395
# 9     Afghanistan      Asia  1997   41.763  22227415   635.341351
# 10    Afghanistan      Asia  2002   42.129  25268405   726.734055
# 11    Afghanistan      Asia  2007   43.828  31889923   974.580338
# 12        Albania    Europe  1952   55.230   1282697  1601.056136
# ...

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (1704, 6)

# %%
df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
df.dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-b959c06452a1> in <module>()
# ----> 1 df.dtype
#
# ~/ml/env/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
df.stypes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-9da08dc7c57f> in <module>()
# ----> 1 df.stypes
#
# ~/ml/env/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'stypes'

# %%
df.dtypes
# Out:
# country       object
# continent     object
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# dtype: object

# %%
country_df = df['country']

# %%
subset = df[['country','continent','year']]

# %%
subset.head()
# Out:
#        country continent  year
# 0  Afghanistan      Asia  1952
# 1  Afghanistan      Asia  1957
# 2  Afghanistan      Asia  1962
# 3  Afghanistan      Asia  1967
# 4  Afghanistan      Asia  1972

# %%
range(1,3)
# Out:
# range(1, 3)

# %%
print(range(1,5))
# Out:
# range(1, 5)

# %%
range[1:3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-91e6476eb3f3> in <module>()
# ----> 1 range[1:3]
#
# TypeError: 'type' object is not subscriptable

# %%
range[1,3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-128837dd85d5> in <module>()
# ----> 1 range[1,3]
#
# TypeError: 'type' object is not subscriptable

# %%
range(1:3)
# Out:
#   File "<ipython-input-25-34941931e10b>", line 1
#     range(1:3)
#            ^
# SyntaxError: invalid syntax

# %%
range(1,7)
# Out:
# range(1, 7)

# %%
range(1,4,1)
# Out:
# range(1, 4)

# %%
list(range(1,4))
# Out:
# [1, 2, 3]

# %%
df.loc[0]
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap        779.445
# Name: 0, dtype: object

# %%
df.loc[1703]
# Out:
# country      Zimbabwe
# continent      Africa
# year             2007
# lifeExp        43.487
# pop          12311143
# gdpPercap     469.709
# Name: 1703, dtype: object

# %%
df.iloc[-1]
# Out:
# country      Zimbabwe
# continent      Africa
# year             2007
# lifeExp        43.487
# pop          12311143
# gdpPercap     469.709
# Name: 1703, dtype: object

# %%
df.loc[-1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/ml/env/lib/python3.5/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1505                 if not ax.contains(key):
# -> 1506                     error()
#    1507             except TypeError as e:
#
# ~/ml/env/lib/python3.5/site-packages/pandas/core/indexing.py in error()
#    1500                                .format(key=key,
# -> 1501                                        axis=self.obj._get_axis_name(axis)))
#    1502
#
# KeyError: 'the label [-1] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-c8e3ddd1947a> in <module>()
# ----> 1 df.loc[-1]
#
# ~/ml/env/lib/python3.5/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1371
# ...

# %% [markdown]
# iloc uses the row number,loc uses the row name and ix first check for the row name and if doesn't found that by the row name then it goes for the row number

# %%
df.ix[[1,5,9]]
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 5  Afghanistan      Asia  1977   38.438  14880372  786.113360
# 9  Afghanistan      Asia  1997   41.763  22227415  635.341351

# %%
df.ix[0,'continent']
# Out:
# 'Asia'

# %%
df.ix[0,1]
# Out:
# 'Asia'

# %%
df.ix[[0,1],['continent','year']]
# Out:
#   continent  year
# 0      Asia  1952
# 1      Asia  1957

# %%
df.groupby(['year','continent'])

# %%
df.groupby(['year','continent'])['lifeExp'].mean()
# Out:
# year  continent
# 1952  Africa       39.135500
#       Americas     53.279840
#       Asia         46.314394
#       Europe       64.408500
#       Oceania      69.255000
# 1957  Africa       41.266346
#       Americas     55.960280
#       Asia         49.318544
#       Europe       66.703067
#       Oceania      70.295000
# 1962  Africa       43.319442
#       Americas     58.398760
#       Asia         51.563223
#       Europe       68.539233
#       Oceania      71.085000
# 1967  Africa       45.334538
#       Americas     60.410920
#       Asia         54.663640
#       Europe       69.737600
#       Oceania      71.310000
# 1972  Africa       47.450942
#       Americas     62.394920
#       Asia         57.319269
#       Europe       70.775033
#       Oceania      71.910000
# 1977  Africa       49.580423
#       Americas     64.391560
#       Asia         59.610556
#       Europe       71.937767
#       Oceania      72.855000
# 1982  Africa       51.592865
# ...

# %%
df1 = pandas.read_csv('/home/shruti/Downloads/2016-pydata-carolinas-pandas-master/data/concat_1.csv')

# %%
df1.head()
# Out:
#     A   B   C   D
# 0  a0  b0  c0  d0
# 1  a1  b1  c1  d1
# 2  a2  b2  c2  d2
# 3  a3  b3  c3  d3

# %%
df2 = pandas.read_csv('/home/shruti/Downloads/2016-pydata-carolinas-pandas-master/data/concat_2.csv')
df3 = pandas.read_csv('/home/shruti/Downloads/2016-pydata-carolinas-pandas-master/data/concat_3.csv')

# %%
df2.head()
# Out:
#     A   B   C   D
# 0  a4  b4  c4  d4
# 1  a5  b5  c5  d5
# 2  a6  b6  c6  d6
# 3  a7  b7  c7  d7

# %%
pandas.concat([df1,df2,df3])
# Out:
#      A    B    C    D
# 0   a0   b0   c0   d0
# 1   a1   b1   c1   d1
# 2   a2   b2   c2   d2
# 3   a3   b3   c3   d3
# 0   a4   b4   c4   d4
# 1   a5   b5   c5   d5
# 2   a6   b6   c6   d6
# 3   a7   b7   c7   d7
# 0   a8   b8   c8   d8
# 1   a9   b9   c9   d9
# 2  a10  b10  c10  d10
# 3  a11  b11  c11  d11

# %%
col_concat=pandas.concat([df1,df2,df3],axis=1)

# %%
col_concat['A']
# Out:
#     A   A    A
# 0  a0  a4   a8
# 1  a1  a5   a9
# 2  a2  a6  a10
# 3  a3  a7  a11

# %%
df1.columns = ['A','R','L','G']
df3.columns = ['P','Q','R','G']

# %%
concatenated = pandas.concat([df1,df2,df3])

# %%
concatenated.to_csv('Saved')

# %%
ls
# Out:
# env/  Numpy_tutorial.ipynb  Pandas_tutorial.ipynb  Saved

# %%
concatenated.iloc[3]
# Out:
# A     a3
# B    NaN
# C    NaN
# D    NaN
# G     d3
# L     c3
# P    NaN
# Q    NaN
# R     b3
# Name: 3, dtype: object

# %%
person = pandas.read_csv('/home/shruti/Downloads/2016-pydata-carolinas-pandas-master/data/survey_person.csv')
visited = pandas.read_csv('/home/shruti/Downloads/2016-pydata-carolinas-pandas-master/data/survey_visited.csv')
survey = pandas.read_csv('/home/shruti/Downloads/2016-pydata-carolinas-pandas-master/data/survey_survey.csv')
site = pandas.read_csv('/home/shruti/Downloads/2016-pydata-carolinas-pandas-master/data/survey_site.csv')

# %%
site
# Out:
#     name    lat    long
# 0   DR-1 -49.85 -128.57
# 1   DR-3 -47.15 -126.72
# 2  MSK-4 -48.87 -123.40

# %%
visited
# Out:
#    ident   site       dated
# 0    619   DR-1  1927-02-08
# 1    622   DR-1  1927-02-10
# 2    734   DR-3  1939-01-07
# 3    735   DR-3  1930-01-12
# 4    751   DR-3  1930-02-26
# 5    752   DR-3         NaN
# 6    837  MSK-4  1932-01-14
# 7    844   DR-1  1932-03-22

# %%
survey
# Out:
#     taken person quant  reading
# 0     619   dyer   rad     9.82
# 1     619   dyer   sal     0.13
# 2     622   dyer   rad     7.80
# 3     622   dyer   sal     0.09
# 4     734     pb   rad     8.41
# 5     734   lake   sal     0.05
# 6     734     pb  temp   -21.50
# 7     735     pb   rad     7.22
# 8     735    NaN   sal     0.06
# 9     735    NaN  temp   -26.00
# 10    751     pb   rad     4.35
# 11    751     pb  temp   -18.50
# 12    751   lake   sal     0.10
# 13    752   lake   rad     2.19
# 14    752   lake   sal     0.09
# 15    752   lake  temp   -16.00
# 16    752    roe   sal    41.60
# 17    837   lake   rad     1.46
# 18    837   lake   sal     0.21
# 19    837    roe   sal    22.50
# 20    844    roe   rad    11.25

# %%
person
# Out:
#       ident   personal    family
# 0      dyer    William      Dyer
# 1        pb      Frank   Pabodie
# 2      lake   Anderson      Lake
# 3       roe  Valentina   Roerich
# 4  danforth      Frank  Danforth

# %%
visited.merge(site,left_on='site',right_on = 'name')
# Out:
#    ident   site       dated   name    lat    long
# 0    619   DR-1  1927-02-08   DR-1 -49.85 -128.57
# 1    622   DR-1  1927-02-10   DR-1 -49.85 -128.57
# 2    844   DR-1  1932-03-22   DR-1 -49.85 -128.57
# 3    734   DR-3  1939-01-07   DR-3 -47.15 -126.72
# 4    735   DR-3  1930-01-12   DR-3 -47.15 -126.72
# 5    751   DR-3  1930-02-26   DR-3 -47.15 -126.72
# 6    752   DR-3         NaN   DR-3 -47.15 -126.72
# 7    837  MSK-4  1932-01-14  MSK-4 -48.87 -123.40

# %%
visited
# Out:
#    ident   site       dated
# 0    619   DR-1  1927-02-08
# 1    622   DR-1  1927-02-10
# 2    734   DR-3  1939-01-07
# 3    735   DR-3  1930-01-12
# 4    751   DR-3  1930-02-26
# 5    752   DR-3         NaN
# 6    837  MSK-4  1932-01-14
# 7    844   DR-1  1932-03-22

# %%
visited = pandas.read_csv('/home/shruti/Downloads/2016-pydata-carolinas-pandas-master/data/survey_visited.csv',keep_default_na=True,na_values=['88'])

# %%
visited
# Out:
#    ident   site       dated
# 0    619   DR-1  1927-02-08
# 1    622   DR-1  1927-02-10
# 2    734   DR-3  1939-01-07
# 3    735   DR-3  1930-01-12
# 4    751   DR-3  1930-02-26
# 5    752   DR-3
# 6    837  MSK-4  1932-01-14
# 7    844   DR-1  1932-03-22

# %%
pandas.isnull(visited.dated)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# 7    False
# Name: dated, dtype: bool
